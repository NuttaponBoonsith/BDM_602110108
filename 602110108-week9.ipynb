# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../input/credit-card-approval-prediction/application_record.csv')

df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0               427500.0               Working               Higher education
# 1               427500.0               Working               Higher education
# 2               112500.0               Working  Secondary / secondary special
# 3               270000.0  Commercial associate  Secondary / secondary special
# 4               270000.0  Commercial associate  Secondary / secondary special
# ...                  ...                   ...                            ...
# 438552          135000.0             Pensioner  Secondary / secondary special
# 438553          103500.0               Working  Secondary / secondary special
# 438554           54000.0  Commercial associate               Higher education
# 438555           72000.0             Pensioner  Secondary / secondary special
# 438556          121500.0               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0             Civil marriage   Rented apartment      -12005          -4542
# 1             Civil marriage   Rented apartment      -12005          -4542
# 2                    Married  House / apartment      -21474          -1134
# 3       Single / not married  House / apartment      -19110          -3051
# 4       Single / not married  House / apartment      -19110          -3051
# ...                      ...                ...         ...            ...
# 438552             Separated  House / apartment      -22717         365243
# 438553  Single / not married  House / apartment      -15939          -3007
# 438554  Single / not married       With parents       -8169           -372
# 438555               Married  House / apartment      -21673         365243
# 438556               Married  House / apartment      -18858          -1201
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  \
# 0                1                1           0           0             NaN
# 1                1                1           0           0             NaN
# 2                1                0           0           0  Security staff
# 3                1                0           1           1     Sales staff
# 4                1                0           1           1     Sales staff
# ...            ...              ...         ...         ...             ...
# 438552           1                0           0           0             NaN
# 438553           1                0           0           0        Laborers
# 438554           1                1           0           0     Sales staff
# 438555           1                0           0           0             NaN
# 438556           1                0           1           0     Sales staff
#
#         CNT_FAM_MEMBERS
# 0                   2.0
# 1                   2.0
# 2                   2.0
# 3                   1.0
# 4                   1.0
# ...                 ...
# 438552              1.0
# 438553              1.0
# 438554              1.0
# 438555              2.0
# 438556              2.0
#
# [438557 rows x 18 columns]

# %%
df_label = pd.read_csv('../input/credit-card-approval-prediction/credit_record.csv')

# %%
df.isnull().sum(axis=0)
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
df_clean = df.dropna(axis = 0)

# %%
df_clean.shape
# Out:
# (304354, 18)

# %%
#y = df_clean['pmmet'].values
#X = df_clean.drop(['pmmet'],axis = 1).values

# %%
df_clean.isnull().sum(axis=0)
# Out:
# ID                     0
# CODE_GENDER            0
# FLAG_OWN_CAR           0
# FLAG_OWN_REALTY        0
# CNT_CHILDREN           0
# AMT_INCOME_TOTAL       0
# NAME_INCOME_TYPE       0
# NAME_EDUCATION_TYPE    0
# NAME_FAMILY_STATUS     0
# NAME_HOUSING_TYPE      0
# DAYS_BIRTH             0
# DAYS_EMPLOYED          0
# FLAG_MOBIL             0
# FLAG_WORK_PHONE        0
# FLAG_PHONE             0
# FLAG_EMAIL             0
# OCCUPATION_TYPE        0
# CNT_FAM_MEMBERS        0
# dtype: int64

# %%
df_clean = df_clean.drop(['DAYS_BIRTH','FLAG_WORK_PHONE','FLAG_EMAIL','CODE_GENDER','FLAG_MOBIL','FLAG_PHONE'],axis = 1)

# %%
df_clean.dtypes
# Out:
# ID                       int64
# FLAG_OWN_CAR            object
# FLAG_OWN_REALTY         object
# CNT_CHILDREN             int64
# AMT_INCOME_TOTAL       float64
# NAME_INCOME_TYPE        object
# NAME_EDUCATION_TYPE     object
# NAME_FAMILY_STATUS      object
# NAME_HOUSING_TYPE       object
# DAYS_EMPLOYED            int64
# OCCUPATION_TYPE         object
# CNT_FAM_MEMBERS        float64
# dtype: object

# %%
df_clean_drop = df_clean

# %%
df_clean_drop
# Out:
#              ID FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 2       5008806            Y               Y             0          112500.0
# 3       5008808            N               Y             0          270000.0
# 4       5008809            N               Y             0          270000.0
# 5       5008810            N               Y             0          270000.0
# 6       5008811            N               Y             0          270000.0
# ...         ...          ...             ...           ...               ...
# 438541  6837707            N               Y             0          202500.0
# 438548  6839936            Y               Y             1          135000.0
# 438553  6840222            N               N             0          103500.0
# 438554  6841878            N               N             0           54000.0
# 438556  6842885            N               Y             0          121500.0
#
#             NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 2                    Working  Secondary / secondary special
# 3       Commercial associate  Secondary / secondary special
# 4       Commercial associate  Secondary / secondary special
# 5       Commercial associate  Secondary / secondary special
# 6       Commercial associate  Secondary / secondary special
# ...                      ...                            ...
# 438541               Working               Higher education
# 438548               Working  Secondary / secondary special
# 438553               Working  Secondary / secondary special
# 438554  Commercial associate               Higher education
# 438556               Working  Secondary / secondary special
#
#           NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_EMPLOYED  \
# 2                    Married  House / apartment          -1134
# 3       Single / not married  House / apartment          -3051
# 4       Single / not married  House / apartment          -3051
# 5       Single / not married  House / apartment          -3051
# 6       Single / not married  House / apartment          -3051
# ...                      ...                ...            ...
# 438541        Civil marriage  House / apartment          -2309
# 438548               Married  House / apartment          -2095
# 438553  Single / not married  House / apartment          -3007
# 438554  Single / not married       With parents           -372
# 438556               Married  House / apartment          -1201
#
#        OCCUPATION_TYPE  CNT_FAM_MEMBERS
# 2       Security staff              2.0
# 3          Sales staff              1.0
# 4          Sales staff              1.0
# 5          Sales staff              1.0
# 6          Sales staff              1.0
# ...                ...              ...
# 438541        Laborers              2.0
# 438548        Laborers              3.0
# 438553        Laborers              1.0
# 438554     Sales staff              1.0
# 438556     Sales staff              2.0
#
# [304354 rows x 12 columns]

# %%
df_label
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
df_label.groupby('ID')['STATUS'].count()
# Out:
# ID
# 5001711     4
# 5001712    19
# 5001713    22
# 5001714    15
# 5001715    60
#            ..
# 5150482    18
# 5150483    18
# 5150484    13
# 5150485     2
# 5150487    30
# Name: STATUS, Length: 45985, dtype: int64

# %%
df_label['STATUS'], labels = pd.factorize(df_label['STATUS'])

# %%
labels
# Out:
# Index(['X', '0', 'C', '1', '2', '3', '4', '5'], dtype='object')

# %%
df_label_clean = df_label[df_label['STATUS'] != 0]

# %%
df_label_clean['STATUS'][df_label['STATUS'] > 2] = 10

# %%
df_label_clean['STATUS'][df_label['STATUS'] <= 2] = 0

# %%
df_label_clean.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0     825151
# 10     14194
# Name: STATUS, dtype: int64

# %%
df_label_clean.groupby('ID').mean()
# Out:
#          MONTHS_BALANCE    STATUS
# ID
# 5001711       -2.000000  0.000000
# 5001712       -9.000000  0.000000
# 5001717      -10.500000  0.000000
# 5001718      -18.724138  0.689655
# 5001719      -21.000000  0.000000
# ...                 ...       ...
# 5150480      -36.500000  0.000000
# 5150482      -19.500000  0.000000
# 5150484       -6.000000  0.000000
# 5150485       -0.500000  0.000000
# 5150487      -14.500000  0.000000
#
# [41449 rows x 2 columns]

# %%
df_label_group = df_label_clean.groupby('ID').mean()

# %%
df_label_group['STATUS'][df_label_group['STATUS'] > 0] = 1
df_label_group['STATUS'][df_label_group['STATUS'] <= 0] = 0

# %%
df_label_group.groupby('STATUS')['STATUS'].count()
# Out:
# STATUS
# 0.0    36099
# 1.0     5350
# Name: STATUS, dtype: int64

# %%
df_label_group
# Out:
#          MONTHS_BALANCE  STATUS
# ID
# 5001711       -2.000000     0.0
# 5001712       -9.000000     0.0
# 5001717      -10.500000     0.0
# 5001718      -18.724138     1.0
# 5001719      -21.000000     0.0
# ...                 ...     ...
# 5150480      -36.500000     0.0
# 5150482      -19.500000     0.0
# 5150484       -6.000000     0.0
# 5150485       -0.500000     0.0
# 5150487      -14.500000     0.0
#
# [41449 rows x 2 columns]

# %%
client_id = df_label_group.index.values
client_label = df_label_group['STATUS'].values

# %%
df.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  4.385570e+05  438557.000000      4.385570e+05  438557.000000
# mean   6.022176e+06       0.427390      1.875243e+05  -15997.904649
# std    5.716370e+05       0.724882      1.100869e+05    4185.030007
# min    5.008804e+06       0.000000      2.610000e+04  -25201.000000
# 25%    5.609375e+06       0.000000      1.215000e+05  -19483.000000
# 50%    6.047745e+06       0.000000      1.607805e+05  -15630.000000
# 75%    6.456971e+06       1.000000      2.250000e+05  -12514.000000
# max    7.999952e+06      19.000000      6.750000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE     FLAG_PHONE  \
# count  438557.000000    438557.0    438557.000000  438557.000000
# mean    60563.675328         1.0         0.206133       0.287771
# std    138767.799647         0.0         0.404527       0.452724
# min    -17531.000000         1.0         0.000000       0.000000
# 25%     -3103.000000         1.0         0.000000       0.000000
# 50%     -1467.000000         1.0         0.000000       0.000000
# 75%      -371.000000         1.0         0.000000       1.000000
# max    365243.000000         1.0         1.000000       1.000000
#
#           FLAG_EMAIL  CNT_FAM_MEMBERS
# count  438557.000000    438557.000000
# mean        0.108207         2.194465
# std         0.310642         0.897207
# min         0.000000         1.000000
# 25%         0.000000         2.000000
# 50%         0.000000         2.000000
# 75%         0.000000         3.000000
# max         1.000000        20.000000

# %%
df.isnull().any()
# Out:
# ID                     False
# CODE_GENDER            False
# FLAG_OWN_CAR           False
# FLAG_OWN_REALTY        False
# CNT_CHILDREN           False
# AMT_INCOME_TOTAL       False
# NAME_INCOME_TYPE       False
# NAME_EDUCATION_TYPE    False
# NAME_FAMILY_STATUS     False
# NAME_HOUSING_TYPE      False
# DAYS_BIRTH             False
# DAYS_EMPLOYED          False
# FLAG_MOBIL             False
# FLAG_WORK_PHONE        False
# FLAG_PHONE             False
# FLAG_EMAIL             False
# OCCUPATION_TYPE         True
# CNT_FAM_MEMBERS        False
# dtype: bool

# %%
df.groupby('OCCUPATION_TYPE')['OCCUPATION_TYPE'].count()
# Out:
# OCCUPATION_TYPE
# Accountants              15985
# Cleaning staff            5845
# Cooking staff             8076
# Core staff               43007
# Drivers                  26090
# HR staff                   774
# High skill tech staff    17289
# IT staff                   604
# Laborers                 78240
# Low-skill Laborers        2140
# Managers                 35487
# Medicine staff           13520
# Private service staff     3456
# Realty agents             1041
# Sales staff              41098
# Secretaries               2044
# Security staff            7993
# Waiters/barmen staff      1665
# Name: OCCUPATION_TYPE, dtype: int64

# %%
df_clean = df.dropna(axis = 0)

# %%
df.groupby('NAME_HOUSING_TYPE')['NAME_HOUSING_TYPE'].count()
# Out:
# NAME_HOUSING_TYPE
# Co-op apartment          1539
# House / apartment      393831
# Municipal apartment     14214
# Office apartment         3922
# Rented apartment         5974
# With parents            19077
# Name: NAME_HOUSING_TYPE, dtype: int64

# %%
df_clean_drop = df_clean.drop(['DAYS_BIRTH', 'FLAG_EMAIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE', 'FLAG_MOBIL'], axis = 1)

# %%
df_clean_drop = df_clean_drop.drop(['CODE_GENDER'], axis = 1)

# %%
df_clean_drop['FLAG_OWN_CAR'] = pd.factorize(df_clean_drop['FLAG_OWN_CAR'])[0]
df_clean_drop['FLAG_OWN_REALTY'] = pd.factorize(df_clean_drop['FLAG_OWN_REALTY'])[0]
df_clean_drop['NAME_INCOME_TYPE'] = pd.factorize(df_clean_drop['NAME_INCOME_TYPE'])[0]
df_clean_drop['NAME_EDUCATION_TYPE'] = pd.factorize(df_clean_drop['NAME_EDUCATION_TYPE'])[0]
df_clean_drop['NAME_FAMILY_STATUS'] = pd.factorize(df_clean_drop['NAME_FAMILY_STATUS'])[0]
df_clean_drop['NAME_HOUSING_TYPE'] = pd.factorize(df_clean_drop['NAME_HOUSING_TYPE'])[0]
df_clean_drop['OCCUPATION_TYPE'] = pd.factorize(df_clean_drop['OCCUPATION_TYPE'])[0]

# %%
X_clien_id = df_clean_drop['ID'].values
df_clean_drop = df_clean_drop.drop(['ID'], axis = 1)

# %%
X = df_clean_drop.values
X.shape
# Out:
# (304354, 11)

# %%
real_client_id = np.array([item for item in X_clien_id if item in client_id])

# %%
y = np.array([client_label[client_id == item][0] for item in real_client_id])

# %%
X_final = [X[X_clien_id == item, :][0] for item in real_client_id]

# %%
X_real_final = np.vstack(X_final)

# %%
from imblearn.under_sampling import RandomUnderSampler
sm = RandomUnderSampler(random_state=1)
X_res, y_res = sm.fit_resample(X_real_final, y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.2, random_state=1)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X_train)
X_train_norm =  scaler.transform(X_train)
X_val_norm = scaler.transform(X_val)
X_test_norm = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

params = {'C': [1, 2, 4, 8, 16]}
clf = GridSearchCV(LogisticRegression(random_state=0, solver='liblinear'),params, cv=10)
clf.fit(X_train_norm, y_train)
print("Best params : " + str(clf.best_params_))
print("10CV accuracy : "+str(clf.best_score_*100))
# Out:
# Best params : {'C': 4}
# 10CV accuracy : 53.40269786472318

# %%
y_predict = clf.predict(X_test_norm)
print("Test accuracy : "+str(sum(y_test == y_predict)/len(y_test)*100))
# Out:
# Test accuracy : 52.02265372168284

# %%
import tensorflow as tf
# Out:
# 2021-09-19 18:25:36.063529: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2021-09-19 18:25:36.063686: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
def create_model():
    tf.random.set_seed(0)
    tf.compat.v1.reset_default_graph() # Clear Model

    model = tf.keras.models.Sequential([
      tf.keras.layers.Dense(100, activation='relu', input_shape=(11,)),
      tf.keras.layers.Dense(50, activation='relu'),
      tf.keras.layers.Dense(25, activation='relu'),
      tf.keras.layers.Dense(5, activation='relu'),
      tf.keras.layers.Dense(3, activation='relu'),
      tf.keras.layers.Dense(1, activation='sigmoid')    
    ])
    return model

# %%
model = create_model()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# 2021-09-19 18:25:58.760408: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-19 18:25:58.763781: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/conda/lib
# 2021-09-19 18:25:58.763821: W tensorflow/stream_executor/cuda/cuda_driver.cc:326] failed call to cuInit: UNKNOWN ERROR (303)
# 2021-09-19 18:25:58.763851: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (da3356b0df87): /proc/driver/nvidia/version does not exist
# 2021-09-19 18:25:58.764277: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-19 18:25:58.764725: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set

# %%
train_acc = list()
val_acc = list()
for i in range(0,200):
  history = model.fit(X_train_norm, y_train, epochs= 1, batch_size = 200, validation_data= (X_val_norm, y_val))
  tmp_avg = np.mean(history.history['accuracy'])
  tmp_avg_val = np.mean(history.history['val_accuracy'])
  train_acc.append(tmp_avg)
  val_acc.append(tmp_avg_val)
# Out:
# 2021-09-19 18:26:08.898961: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-19 18:26:08.913047: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2199995000 Hz
# 20/20 [==============================] - 1s 32ms/step - loss: 0.6931 - accuracy: 0.5013 - val_loss: 0.6928 - val_accuracy: 0.5086
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6921 - accuracy: 0.5323 - val_loss: 0.6935 - val_accuracy: 0.5046
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6918 - accuracy: 0.5325 - val_loss: 0.6929 - val_accuracy: 0.4965
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6912 - accuracy: 0.5353 - val_loss: 0.6928 - val_accuracy: 0.5046
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6908 - accuracy: 0.5386 - val_loss: 0.6932 - val_accuracy: 0.4954
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6906 - accuracy: 0.5371 - val_loss: 0.6926 - val_accuracy: 0.5207
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6901 - accuracy: 0.5371 - val_loss: 0.6926 - val_accuracy: 0.5217
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6895 - accuracy: 0.5441 - val_loss: 0.6927 - val_accuracy: 0.5207
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6891 - accuracy: 0.5449 - val_loss: 0.6927 - val_accuracy: 0.5217
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6886 - accuracy: 0.5462 - val_loss: 0.6926 - val_accuracy: 0.5157
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6881 - accuracy: 0.5464 - val_loss: 0.6926 - val_accuracy: 0.5228
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6877 - accuracy: 0.5502 - val_loss: 0.6926 - val_accuracy: 0.5248
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6872 - accuracy: 0.5505 - val_loss: 0.6924 - val_accuracy: 0.5248
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6866 - accuracy: 0.5520 - val_loss: 0.6925 - val_accuracy: 0.5258
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6861 - accuracy: 0.5548 - val_loss: 0.6928 - val_accuracy: 0.5187
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6856 - accuracy: 0.5565 - val_loss: 0.6927 - val_accuracy: 0.5238
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6848 - accuracy: 0.5583 - val_loss: 0.6926 - val_accuracy: 0.5228
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6839 - accuracy: 0.5601 - val_loss: 0.6921 - val_accuracy: 0.5379
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6825 - accuracy: 0.5694 - val_loss: 0.6910 - val_accuracy: 0.5298
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6811 - accuracy: 0.5727 - val_loss: 0.6906 - val_accuracy: 0.5349
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6797 - accuracy: 0.5712 - val_loss: 0.6899 - val_accuracy: 0.5420
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6785 - accuracy: 0.5722 - val_loss: 0.6902 - val_accuracy: 0.5480
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6768 - accuracy: 0.5770 - val_loss: 0.6907 - val_accuracy: 0.5460
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6753 - accuracy: 0.5773 - val_loss: 0.6905 - val_accuracy: 0.5359
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6742 - accuracy: 0.5760 - val_loss: 0.6926 - val_accuracy: 0.5339
# 20/20 [==============================] - 0s 10ms/step - loss: 0.
- val_accuracy: 0.5339
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6290 - accuracy: 0.6456 - val_loss: 0.7276 - val_accuracy: 0.5298
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6277 - accuracy: 0.6474 - val_loss: 0.7216 - val_accuracy: 0.5298
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6251 - accuracy: 0.6547 - val_loss: 0.7192 - val_accuracy: 0.5369
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6237 - accuracy: 0.6524 - val_loss: 0.7250 - val_accuracy: 0.5339
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6230 - accuracy: 0.6514 - val_loss: 0.7268 - val_accuracy: 0.5329
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6212 - accuracy: 0.6527 - val_loss: 0.7246 - val_accuracy: 0.5339
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6205 - accuracy: 0.6562 - val_loss: 0.7306 - val_accuracy: 0.5379
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6190 - accuracy: 0.6562 - val_loss: 0.7268 - val_accuracy: 0.5379
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6161 - accuracy: 0.6635 - val_loss: 0.7261 - val_accuracy: 0.5288
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6142 - accuracy: 0.6668 - val_loss: 0.7339 - val_accuracy: 0.5379
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6146 - accuracy: 0.6648 - val_loss: 0.7255 - val_accuracy: 0.5369
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6129 - accuracy: 0.6643 - val_loss: 0.7233 - val_accuracy: 0.5430
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6118 - accuracy: 0.6648 - val_loss: 0.7288 - val_accuracy: 0.5410
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6128 - accuracy: 0.6658 - val_loss: 0.7380 - val_accuracy: 0.5379
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6123 - accuracy: 0.6625 - val_loss: 0.7390 - val_accuracy: 0.5308
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6105 - accuracy: 0.6656 - val_loss: 0.7411 - val_accuracy: 0.5298
# 20/20 [==============================] - 0s 11ms/step - loss: 0.6073 - accuracy: 0.6729 - val_loss: 0.7394 - val_accuracy: 0.5379
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6063 - accuracy: 0.6704 - val_loss: 0.7362 - val_accuracy: 0.5339
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6048 - accuracy: 0.6719 - val_loss: 0.7354 - val_accuracy: 0.5460
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6041 - accuracy: 0.6747 - val_loss: 0.7402 - val_accuracy: 0.5410
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6024 - accuracy: 0.6782 - val_loss: 0.7375 - val_accuracy: 0.5389
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6010 - accuracy: 0.6787 - val_loss: 0.7396 - val_accuracy: 0.5480
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6015 - accuracy: 0.6820 - val_loss: 0.7314 - val_accuracy: 0.5521
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6006 - accuracy: 0.6820 - val_loss: 0.7351 - val_accuracy: 0.5420
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5997 - accuracy: 0.6805 - val_loss: 0.7346 - val_accuracy: 0.5430
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5994 - accuracy: 0.6823 - val_loss: 0.7334 - val_accuracy: 0.5399
# 20/20 [==============================] - 0s 11ms/step - loss: 0.5986 - accuracy: 0.6843 - val_loss: 0.7342 - val_accuracy: 0.5440
# 20/20 [==============================] - 0s 12ms/step - loss: 0.6011 - accuracy: 0.6835 - val_loss: 0.7292 - val_accuracy: 0.5531
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6014 - accuracy: 0.6752 - val_loss: 0.7407 - val_accuracy: 0.5460
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6010 - accuracy: 0.6770 - val_loss: 0.7475 - val_accuracy: 0.5480
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5987 - accuracy: 0.6764 - val_loss: 0.7334 - val_accuracy: 0.5531
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5983 - accuracy: 0.6797 - val_loss: 0.7363 - val_accuracy: 0.5480
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5975 - accuracy: 0.6805 - val_loss: 0.7360 - val_accuracy: 0.5470
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5963 - accuracy: 0.6818 - val_loss: 0.7353 - val_accuracy: 0.5450
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5952 - accuracy: 0.6818 - val_loss: 0.7281 - val_accuracy: 0.5470
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5980 - accuracy: 0.6762 - val_loss: 0.7311 - val_accuracy: 0.5480
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6012 - accuracy: 0.6739 - val_loss: 0.7461 - val_accuracy: 0.5379
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6045 - accuracy: 0.6732 - val_loss: 0.7415 - val_accuracy: 0.5440
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6031 - accuracy: 0.6747 - val_loss: 0.7356 - val_accuracy: 0.5430
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6023 - accuracy: 0.6802 - val_loss: 0.7439 - val_accuracy: 0.5410
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6078 - accuracy: 0.6646 - val_loss: 0.7336 - val_accuracy: 0.5501
# 20/20 [==============================] - 0s 10ms/step - loss: 0.6115 - accuracy: 0.6653 - val_loss: 0.7165 - val_accuracy: 0.5470
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6092 - accuracy: 0.6696 - val_loss: 0.7291 - val_accuracy: 0.5501
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6050 - accuracy: 0.6744 - val_loss: 0.7277 - val_accuracy: 0.5460
# 20/20 [==============================] - 0s 9ms/step - loss: 0.6027 - accuracy: 0.6744 - val_loss: 0.7364 - val_accuracy: 0.5470
# 20/20 [==============================] - 0s 10ms/step - loss: 0.
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5661 - accuracy: 0.7025 - val_loss: 0.7308 - val_accuracy: 0.5501
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5654 - accuracy: 0.7060 - val_loss: 0.7367 - val_accuracy: 0.5531
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5650 - accuracy: 0.7028 - val_loss: 0.7389 - val_accuracy: 0.5612
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5636 - accuracy: 0.7012 - val_loss: 0.7375 - val_accuracy: 0.5622
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5637 - accuracy: 0.7005 - val_loss: 0.7370 - val_accuracy: 0.5632
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5644 - accuracy: 0.7033 - val_loss: 0.7406 - val_accuracy: 0.5531
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5655 - accuracy: 0.6990 - val_loss: 0.7430 - val_accuracy: 0.5551
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5618 - accuracy: 0.7083 - val_loss: 0.7438 - val_accuracy: 0.5652
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5597 - accuracy: 0.7093 - val_loss: 0.7491 - val_accuracy: 0.5602
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5596 - accuracy: 0.7093 - val_loss: 0.7505 - val_accuracy: 0.5592
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5593 - accuracy: 0.7073 - val_loss: 0.7597 - val_accuracy: 0.5622
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5601 - accuracy: 0.7073 - val_loss: 0.7631 - val_accuracy: 0.5662
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5612 - accuracy: 0.7060 - val_loss: 0.7594 - val_accuracy: 0.5612
# 20/20 [==============================] - 0s 11ms/step - loss: 0.5614 - accuracy: 0.7088 - val_loss: 0.7624 - val_accuracy: 0.5642
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5592 - accuracy: 0.7109 - val_loss: 0.7658 - val_accuracy: 0.5632
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5607 - accuracy: 0.7081 - val_loss: 0.7621 - val_accuracy: 0.5521
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5601 - accuracy: 0.7106 - val_loss: 0.7610 - val_accuracy: 0.5571
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5595 - accuracy: 0.7101 - val_loss: 0.7570 - val_accuracy: 0.5592
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5596 - accuracy: 0.7088 - val_loss: 0.7621 - val_accuracy: 0.5622
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5609 - accuracy: 0.7083 - val_loss: 0.7568 - val_accuracy: 0.5602
# 20/20 [==============================] - 0s 11ms/step - loss: 0.5608 - accuracy: 0.7025 - val_loss: 0.7610 - val_accuracy: 0.5551
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5602 - accuracy: 0.7073 - val_loss: 0.7557 - val_accuracy: 0.5592
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5662 - accuracy: 0.7007 - val_loss: 0.7549 - val_accuracy: 0.5551
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5658 - accuracy: 0.7010 - val_loss: 0.7500 - val_accuracy: 0.5642
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5699 - accuracy: 0.6964 - val_loss: 0.7413 - val_accuracy: 0.5804
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5654 - accuracy: 0.7023 - val_loss: 0.7419 - val_accuracy: 0.5763
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5656 - accuracy: 0.7010 - val_loss: 0.7471 - val_accuracy: 0.5622
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5626 - accuracy: 0.7055 - val_loss: 0.7423 - val_accuracy: 0.5662
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5614 - accuracy: 0.7076 - val_loss: 0.7474 - val_accuracy: 0.5652
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5565 - accuracy: 0.7106 - val_loss: 0.7472 - val_accuracy: 0.5612
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5573 - accuracy: 0.7066 - val_loss: 0.7471 - val_accuracy: 0.5652
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5576 - accuracy: 0.7106 - val_loss: 0.7488 - val_accuracy: 0.5662
# 20/20 [==============================] - 0s 11ms/step - loss: 0.5570 - accuracy: 0.7086 - val_loss: 0.7512 - val_accuracy: 0.5602
# 20/20 [==============================] - 0s 9ms/step - loss: 0.5562 - accuracy: 0.7129 - val_loss: 0.7546 - val_accuracy: 0.5642
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5581 - accuracy: 0.7116 - val_loss: 0.7592 - val_accuracy: 0.5632
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5584 - accuracy: 0.7088 - val_loss: 0.7560 - val_accuracy: 0.5723
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5574 - accuracy: 0.7101 - val_loss: 0.7656 - val_accuracy: 0.5662
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5556 - accuracy: 0.7144 - val_loss: 0.7714 - val_accuracy: 0.5652
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5553 - accuracy: 0.7141 - val_loss: 0.7782 - val_accuracy: 0.5581
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5550 - accuracy: 0.7146 - val_loss: 0.7827 - val_accuracy: 0.5581
# 20/20 [==============================] - 0s 10ms/step - loss: 0.5542 - accuracy: 0.7152 - val_loss: 0.7793 - val_accuracy: 0.5612
